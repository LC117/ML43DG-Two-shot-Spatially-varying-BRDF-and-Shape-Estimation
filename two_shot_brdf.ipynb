# %% [markdown]
# # Two Shot BRDF with PyTorch

# %% [markdown]
# ## 1. Data Loading
# ### 1.1 Downloading the original dataset
#
# The dataset which is used by Boss et al. can be found at (https://drive.google.com/file/d/14mou3Va65deimPYE5GtFdK8OS3I0BSzq/view). To download the full **98GB** dataset execute the following cell:

# %%
# !gdown https://drive.google.com/u/0/uc?id=14mou3Va65deimPYE5GtFdK8OS3I0BSzq&export=download

# %% [markdown]
# Import libraries (the same ones from the exercises)

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import numpy as np
import matplotlib as plt
#import k3d
#import trimesh
import torch
#import skimage

# %% [markdown]
# Create dataset with the overfit-split to check if paths are set up correctly in the path-manager

# %%
import src.data.dataloader as dt
overfit_dt = dt.TwoShotBrdfData("overfit")

# %%
# Visualize an Item from overfit split
from matplotlib.pyplot import imshow
item = overfit_dt[2]
imshow(item["cam1"], interpolation='nearest')

# %%
imshow(item["flash"], interpolation='nearest')
